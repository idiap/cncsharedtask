# %%
# %load_ext autoreload
# %autoreload 2

import os
import pandas as pd
import numpy as np
# Text preprocessing/analysis
import re
import nltk
from nltk import word_tokenize, sent_tokenize, FreqDist
from nltk.util import ngrams
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
# Visualisation
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid", context='talk', 
        palette=['#D44D5C', '#43AA8B'])

# %%
while not os.getcwd().endswith("CauseEffect_SharedTask"):
    os.chdir("../")
os.getcwd()
# Out:
# '/home/ifajcik/research/CauseEffect_SharedTask'

# %%
subtask_data = "data/train_subtask2.csv"

# %%
subtask_df = pd.read_csv(subtask_data)
subtask_df.head()
# Out:
#   corpus       doc_id  sent_id  eg_id                index  \
# 0    cnc  train_01_10        0      0  cnc_train_01_10_0_0
# 1    cnc  train_01_17        0      0  cnc_train_01_17_0_0
# 2    cnc  train_01_47        0      0  cnc_train_01_47_0_0
# 3    cnc  train_01_70        0      0  cnc_train_01_70_0_0
# 4    cnc  train_01_83        0      0  cnc_train_01_83_0_0
#
#                                                 text  \
# 0  The farmworkers ' strike resumed on Tuesday wh...
# 1  The attack on Karayogams had sparked sharp rea...
# 2  The strike began on September 9 , with Numsa d...
# 3  Some police personnel intervened and urged the...
# 4         Two bus drivers were hurt in the attacks .
#
#                                         text_w_pairs  seq_label  pair_label  \
# 0  <ARG1>The farmworkers ' strike resumed on Tues...          1           1
# 1  <ARG0>The attack on Karayogams</ARG0> <ARG1>ha...          1           1
# 2  <ARG1>The strike began on September 9</ARG1> ,...          1           1
# 3  <ARG0>Some police personnel intervened</ARG0> ...          1           1
# 4  <ARG1>Two bus drivers were hurt</ARG1> in <ARG...          1           1
#
#    context  num_sents
# 0      NaN          1
# 1      NaN          1
# 2      NaN          1
# 3      NaN          1
# 4      NaN          1

# %%
#did this just to check if there are more than 1 sentence in each sample
subtask_df.describe()
# Out:
#        sent_id       eg_id  seq_label  pair_label  context  num_sents
# count    183.0  183.000000      183.0       183.0      0.0      183.0
# mean       0.0    0.147541        1.0         1.0      NaN        1.0
# std        0.0    0.425921        0.0         0.0      NaN        0.0
# min        0.0    0.000000        1.0         1.0      NaN        1.0
# 25%        0.0    0.000000        1.0         1.0      NaN        1.0
# 50%        0.0    0.000000        1.0         1.0      NaN        1.0
# 75%        0.0    0.000000        1.0         1.0      NaN        1.0
# max        0.0    3.000000        1.0         1.0      NaN        1.0

# %%
w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
lemmatizer = nltk.stem.WordNetLemmatizer()

# %%
def lemmatize_text(text):
    return [lemmatizer.lemmatize(w.lower()) for w in w_tokenizer.tokenize(text)]

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /home/ifajcik/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/ifajcik/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
subtask_df['lemmas'] = subtask_df.text.apply(lemmatize_text)
subtask_df["tokens"] = subtask_df.text.apply(nltk.word_tokenize)
subtask_df["posR"] =  subtask_df.tokens.apply(lambda x: nltk.pos_tag(x))
tags = [[tag for word, tag in _] for _ in subtask_df["posR"].to_list()]
subtask_df["pos"] =  tags

# %%
subtask_df.head()
# Out:
#   corpus       doc_id  sent_id  eg_id                index  \
# 0    cnc  train_01_10        0      0  cnc_train_01_10_0_0
# 1    cnc  train_01_17        0      0  cnc_train_01_17_0_0
# 2    cnc  train_01_47        0      0  cnc_train_01_47_0_0
# 3    cnc  train_01_70        0      0  cnc_train_01_70_0_0
# 4    cnc  train_01_83        0      0  cnc_train_01_83_0_0
#
#                                                 text  \
# 0  The farmworkers ' strike resumed on Tuesday wh...
# 1  The attack on Karayogams had sparked sharp rea...
# 2  The strike began on September 9 , with Numsa d...
# 3  Some police personnel intervened and urged the...
# 4         Two bus drivers were hurt in the attacks .
#
#                                         text_w_pairs  seq_label  pair_label  \
# 0  <ARG1>The farmworkers ' strike resumed on Tues...          1           1
# 1  <ARG0>The attack on Karayogams</ARG0> <ARG1>ha...          1           1
# 2  <ARG1>The strike began on September 9</ARG1> ,...          1           1
# 3  <ARG0>Some police personnel intervened</ARG0> ...          1           1
# 4  <ARG1>Two bus drivers were hurt</ARG1> in <ARG...          1           1
#
#    context  num_sents                                             lemmas  \
# 0      NaN          1  [the, farmworkers, ', strike, resumed, on, tue...
# 1      NaN          1  [the, attack, on, karayogams, had, sparked, sh...
# 2      NaN          1  [the, strike, began, on, september, 9, ,, with...
# 3      NaN          1  [some, police, personnel, intervened, and, urg...
# 4      NaN          1  [two, bus, driver, were, hurt, in, the, attack...
#
#                                               tokens  \
# 0  [The, farmworkers, ', strike, resumed, on, Tue...
# 1  [The, attack, on, Karayogams, had, sparked, sh...
# 2  [The, strike, began, on, September, 9, ,, with...
# 3  [Some, police, personnel, intervened, and, urg...
# 4  [Two, bus, drivers, were, hurt, in, the, attac...
#
#                                                 posR  \
# 0  [(The, DT), (farmworkers, NNS), (', POS), (str...
# 1  [(The, DT), (attack, NN), (on, IN), (Karayogam...
# 2  [(The, DT), (strike, NN), (began, VBD), (on, I...
# 3  [(Some, DT), (police, NN), (personnel, NNS), (...
# 4  [(Two, CD), (bus, NN), (drivers, NNS), (were, ...
#
#                                                  pos
# 0  [DT, NNS, POS, NN, VBD, IN, NNP, WRB, PRP$, NN...
# 1  [DT, NN, IN, NNP, VBD, VBN, JJ, NNS, IN, DT, N...
# 2  [DT, NN, VBD, IN, NNP, CD, ,, IN, NNP, VBG, DT...
# 3  [DT, NN, NNS, VBD, CC, VBD, PRP, TO, VB, RP, P...
# 4            [CD, NN, NNS, VBD, VBN, IN, DT, NNS, .]

# %%
def replace_labels(s):
    s = s.replace("<ARG0>","")
    s = s.replace("</ARG0>","")
    s = s.replace("<ARG1>","")
    s = s.replace("</ARG1>","")
    s = s.replace("<SIG0>","")
    s = s.replace("</SIG0>","")
    return s

# %%
args0=[]
args1=[]
sigs0=[]
arg0_regex = re.compile(r"(<ARG0>)(.*)(<\/ARG0>)")
arg1_regex = re.compile(r"(<ARG1>)(.*)(<\/ARG1>)")
sig0_regex = re.compile(r"(<SIG0>)(.*)(<\/SIG0>)")

for s in subtask_df.text_w_pairs.to_list():
    #print (s)
    match_arg0 = arg0_regex.search(s.strip())
    match_arg1 = arg1_regex.search(s.strip())
    match_sig0 = sig0_regex.search(s.strip())
    if match_arg0:
        arg0 = match_arg0.group()
        arg0 = replace_labels(arg0)
        args0.append(arg0)
        #print('Match found: {}\n: '.format(arg0))
    if match_arg1:
        arg1 = match_arg1.group()
        arg1 = replace_labels(arg1)
        args1.append(arg1)
    if match_sig0:
        sig0 = match_sig0.group()
        sig0 = replace_labels(sig0)
        sigs0.append(sig0)
    else:
        sigs0.append('')
        
#print(args0,'\n')
#print(args1,'\n')
#print(sigs0,'\n')
subtask_df['args0'] = args0
subtask_df['args1'] = args1
subtask_df['sigs0'] = sigs0
columns = ['args0','args1','sigs0']
subtask_df[columns].head(10)
# Out:
#                                                args0  \
# 0                         their demands were not met
# 1                           The attack on Karayogams
# 2  with Numsa demanding a double-digit percentage...
# 3                   Some police personnel intervened
# 4                                        the attacks
# 5  Hartal supporters pelted stones at a KSRTC bus...
# 6                          The violence in Yuen Long
# 7  he could provide clues in resolving the blast ...
# 8              allegedly being involved in the blast
# 9                                   use of the field
#
#                                               args1           sigs0
# 0       The farmworkers ' strike resumed on Tuesday
# 1  had sparked sharp reactions from the CPM leaders         sparked
# 2                   The strike began on September 9       demanding
# 3               urged them to give up their protest
# 4                         Two bus drivers were hurt
# 5                              injuring driver Babu        injuring
# 6  heightened tensions and fears of further attacks  has heightened
# 7               The NIA wanted to catch Akram alive              as
# 8               Two more youths were arrested later             for
# 9                              The clash took place            over

# %%
args0_string = " ".join(subtask_df.args0)
args1_string = " ".join(subtask_df.args1)
sigs0_string = " ".join(subtask_df.sigs0)
args0_splits = args0_string.split()
args1_splits = args1_string.split()
sigs0_splits = sigs0_string.split()
print("Number of strings (tokens) in ARGS0:{}, ARGS1:{}, SIGS0:{}".format(len(args0_splits),len(args1_splits),len(sigs0_splits)))
print("Number of unique strings (vocabulary) in ARGS0:{}, ARGS1:{}, SIGS0:{}".format(len(set(args0_splits)), len(set(args1_splits)),len(set(sigs0_splits))))
# Out:
# Number of strings (tokens) in ARGS0:977, ARGS1:1264, SIGS0:176
# Number of unique strings (vocabulary) in ARGS0:508, ARGS1:632, SIGS0:78

# %%
args0_freq_splits = FreqDist(args0_splits)
args1_freq_splits = FreqDist(args1_splits)
sigs0_freq_splits = FreqDist(sigs0_splits)
print(F"***** 10 most common strings ARGS0 ***** \n{args0_freq_splits.most_common(10)}", "\n")
print(F"***** 10 most common strings ARGS1 ***** \n{args1_freq_splits.most_common(10)}", "\n")
print(F"***** 10 most common strings SIGS0 ***** \n{sigs0_freq_splits.most_common(10)}", "\n")
# Out:
# ***** 10 most common strings ARGS0 *****
# [('the', 90), ('to', 35), ('a', 28), ('of', 28), ('in', 23), ('The', 15), ('and', 14), ('their', 13), ('on', 12), ('protest', 12)]
#
# ***** 10 most common strings ARGS1 *****
# [('the', 54), ('to', 30), ('were', 25), ('a', 25), ('The', 23), ('on', 22), ('was', 22), ('in', 21), ('and', 20), ('of', 20)]
#
# ***** 10 most common strings SIGS0 *****
# [('to', 21), ('for', 12), ('of', 10), ('demanding', 8), ('by', 7), ('as', 6), ('in', 5), ('following', 4), ('left', 4), ('protesting', 3)]

# %%
def summarise(pattern, strings, freq):
    """Summarise strings matching a pattern."""
    # Find matches
    compiled_pattern = re.compile(pattern)
    matches = [s for s in strings if compiled_pattern.search(s)]
    
    # Print volume and proportion of matches
    print("{} strings, that is {:.2%} of total".format(len(matches), len(matches)/ len(strings)))
    
    # Create list of tuples containing matches and their frequency
    output = [(s, freq[s]) for s in set(matches)]
    output.sort(key=lambda x:x[1], reverse=True)
    
    return output

# %%
#how frequent are numbers?
print("ARGS0")
print(summarise(r"\d", args0_splits, args0_freq_splits),'\n')
print("ARGS1")
print(summarise(r"\d", args1_splits, args1_freq_splits),'\n')
print("SIGS0")
print(summarise(r"\d", sigs0_splits, sigs0_freq_splits),'\n')
# Out:
# ARGS0
# 9 strings, that is 0.92% of total
# [('2008', 2), ('26', 1), ('R9000', 1), ('<SIG1>to</SIG1>', 1), ('200', 1), ('R16,000', 1), ('50', 1), ('48', 1)]
#
# ARGS1
# 26 strings, that is 2.06% of total
# [('12', 2), ('<SIG1>condemned</SIG1>', 1), ('250', 1), ('65', 1), ('30,000', 1), ('1956', 1), ('<SIG1>embolden</SIG1>', 1), ('25', 1), ('10,000', 1), ('76', 1), ('69', 1), ('4:45am', 1), ('20,000', 1), ('58', 1), ('9', 1), ('55', 1), ('166', 1), ('<SIG2>stirring</SIG2>', 1), ('120', 1), ('13', 1), ('17,200', 1), ('700', 1), ('60,000', 1), ('417', 1), ('38', 1)]
#
# SIGS0
# 0 strings, that is 0.00% of total
# []

# %%
from collections import defaultdict

texts = list(subtask_df.text)
annotations = subtask_df.text_w_pairs.to_list()

multiann_dict = defaultdict(lambda:[])

sent_counts=[]
for i,s in enumerate(texts):
    sent_counts.append(texts.count(s))
    multiann_dict[s].append(annotations[i])
    
assert 0 not in sent_counts
print(f"Average # of annotations per sentence is: {sum(sent_counts)/len(sent_counts):.2f}")
# Out:
# Average # of annotations per sentence is: 1.30

# %%
total_multianncases = 0
for k,v in multiann_dict.items():
    if len(v)>1:
        total_multianncases+=1
        print(f"Sentence:\n{k}")
        print("*"*20)
        joined_annotations = '\n----\n'.join(v)
        print(f"Annotations:\n{joined_annotations}")
        print("\n\n")
# Out:
# Sentence:
# Shiv Sena workers , including some legislators , today staged demonstrations against Karnataka Chief Minister B S Yeddyurappa here , protesting the ' forcible installation ' of a Kannadiga mayor in Marathi-dominated Belgaum city .
# ********************
# Annotations:
# <ARG1>Shiv Sena workers , including some legislators , today staged demonstrations against Karnataka Chief Minister B S Yeddyurappa here</ARG1> , <ARG0><SIG0>protesting</SIG0> the ' forcible installation ' of a Kannadiga mayor in Marathi-dominated Belgaum city</ARG0> .
# ----
# <ARG1>Shiv Sena workers , including some legislators , today staged demonstrations</ARG1> <ARG0>against Karnataka Chief Minister B S Yeddyurappa</ARG0> here , protesting the ' forcible installation ' of a Kannadiga mayor in Marathi-dominated Belgaum city .
#
#
#
# Sentence:
# Following the incident , the labourers went on a dharna and stopped work .
# ********************
# Annotations:
# <SIG0>Following</SIG0> <ARG0>the incident</ARG0> , <ARG1>the labourers went on a dharna</ARG1> and stopped work .
# ----
# Following the incident , <ARG0>the labourers went on a dharna</ARG0> and <ARG1>stopped work</ARG1> .
#
#
#
# Sentence:
# The blockade was lifted following an assurance from ADM Debraj Senapati and the additional SP J. Mahapatra to apprise the State Government of their demand .
# ********************
# Annotations:
# <ARG1>The blockade was lifted</ARG1> <SIG0>following</SIG0> <ARG0>an assurance from ADM Debraj Senapati and the additional SP J. Mahapatra</ARG0> to apprise the State Government of their demand .
# ----
# <ARG1>The blockade was lifted</ARG1> following an assurance from ADM Debraj Senapati and the additional SP J. Mahapatra <ARG0><SIG0>to</SIG0> apprise the State Government of their demand</ARG0> .
#
#
#
# Sentence:
# The clashes erupted after a youth belonging to a minority Muslim sect was allegedly severely injured in a thrashing by a youth from the majority sect following an altercation .
# ********************
# Annotations:
# <ARG1>The clashes erupted</ARG1> after <ARG0>a youth belonging to a minority Muslim sect was allegedly severely injured in a thrashing by a youth from the majority sect</ARG0> following an altercation .
# ----
# The clashes erupted after <ARG1>a youth belonging to a minority Muslim sect was allegedly severely injured in a thrashing by a youth from the majority sect</ARG1> <SIG0>following</SIG0> <ARG0>an altercation</ARG0> .
#
#
#
# Sentence:
# On this day in 1956 around 20,000 women participated in a national march to protest against pass law legislation , which required non-white South Africans to carry a document on them to prove that they were allowed to enter `` white areas '' .
# ********************
# Annotations:
# <ARG1>On this day in 1956 around 20,000 women participated in a national march</ARG1> <ARG0><SIG0>to</SIG0> protest</ARG0> against pass law legislation , which required non-white South Africans to carry a document on them to prove that they were allowed to enter `` white areas '' .
# ----
# On this day in 1956 around 20,000 women participated in a national march <ARG1>to protest</ARG1> <ARG0>against pass law legislation</ARG0> , which required non-white South Africans to carry a document on them to prove that they were allowed to enter `` white areas '' .
# ----
# On this day in 1956 around 20,000 women participated in a national march to protest against pass law legislation , <ARG1>which required non-white South Africans to carry a document on them</ARG1> <ARG0><SIG0>to</SIG0> prove that they were allowed to enter `` white areas ''</ARG0> .
#
#
#
# Sentence:
# The incident triggered outrage across the country and was condemned as despicable and shameful stirring memories of a similar attack last December in New Delhi that sparked nationwide protests .
# ********************
# Annotations:
# <ARG0>The incident</ARG0> <ARG1><SIG0>triggered</SIG0> outrage across the country and was <SIG1>condemned</SIG1> as despicable and shameful <SIG2>stirring</SIG2> memories of a similar attack last December in New Delhi that sparked nationwide protests</ARG1> .
# ----
# The incident triggered outrage across the country and was condemned as despicable and shameful stirring memories of <ARG0>a similar attack last December in New Delhi</ARG0> <SIG0>that <ARG1>sparked</SIG0> nationwide protests</ARG1> .
#
#
#
# Sentence:
# Earlier , residents gathered outside the police station to protest about the murders .
# ********************
# Annotations:
# Earlier , <ARG1>residents gathered outside the police station</ARG1> <ARG0><SIG0>to</SIG0> protest</ARG0> about the murders .
# ----
# Earlier , residents gathered outside the police station <ARG1>to protest</ARG1> <SIG0>about</SIG0> <ARG0>the murders</ARG0> .
#
#
#
# Sentence:
# Violence broke out when DYFI members protested against a Youth Congress meeting being held at the junction .
# ********************
# Annotations:
# <ARG1>Violence broke out</ARG1> when <ARG0>DYFI members protested</ARG0> against a Youth Congress meeting being held at the junction .
# ----
# Violence broke out when <ARG1>DYFI members protested</ARG1> <ARG0>against a Youth Congress meeting being held at the junction</ARG0> .
#
#
#
# Sentence:
# The decision was taken after hundreds of KSRP personnel and their family members staged a protest in Koramangala blocking traffic for more than eight hours on Wednesday .
# ********************
# Annotations:
# <ARG1>The decision was taken</ARG1> after <ARG0>hundreds of KSRP personnel and their family members staged a protest in Koramangala</ARG0> blocking traffic for more than eight hours on Wednesday .
# ----
# The decision was taken after <ARG0>hundreds of KSRP personnel and their family members staged a protest in Koramangala</ARG0> <ARG1><SIG0>blocking</SIG0> traffic for more than eight hours on Wednesday</ARG1> .
#
#
#
# Sentence:
# In all , three persons who included two MRPS workers died in the incident due to burns .
# ********************
# Annotations:
# In all , <ARG1>three persons who included two MRPS workers died</ARG1> in the incident <SIG0>due to</SIG0> <ARG0>burns</ARG0> .
# ----
# In all , <ARG1>three persons who included two MRPS workers died</ARG1> in <ARG0>the incident</ARG0> due to burns .
#
#
#
# Sentence:
# Two protestors were shot dead , allegedly by police , on Monday during a service delivery protest .
# ********************
# Annotations:
# <ARG1>Two protestors were shot dead , allegedly by police , on Monday</ARG1> during <ARG0>a service delivery protest</ARG0> .
# ----
# <ARG1>Two protestors were shot dead</ARG1> , allegedly <SIG0>by</SIG0> <ARG0>police , on Monday during a service delivery protest</ARG0> .
#
#
#
# Sentence:
# In retaliation , the police fired a few rounds in the air which finally capped the clashes .
# ********************
# Annotations:
# In <ARG0>retaliation</ARG0> , <ARG1>the police fired a few rounds in the air</ARG1> which finally capped the clashes .
# ----
# In retaliation , <ARG0>the police fired a few rounds in the air</ARG0> <ARG1>which finally capped the clashes</ARG1> .
#
#
#
# Sentence:
# Lack of medical services because of the strike left several patients in agony .
# ********************
# Annotations:
# <ARG1>Lack of medical services</ARG1> <SIG0>because of</SIG0> <ARG0>the strike</ARG0> left several patients in agony .
# ----
# <ARG0>Lack of medical services</ARG0> because of the strike <ARG1><SIG0>left</SIG0> several patients in agony</ARG1> .
#
#
#
# Sentence:
# Thirty people were killed in the agitation , which also saw large scale damage to property .
# ********************
# Annotations:
# <ARG1>Thirty people were killed</ARG1> in <ARG0>the agitation</ARG0> , which also saw large scale damage to property .
# ----
# Thirty people were killed in <ARG0>the agitation</ARG0> , <ARG1>which also saw large scale damage to property</ARG1> .
#
#
#
# Sentence:
# But as we work for the people , we obliged their request and released the men , ” said a Maoist leader who handed over the abducted to the tribal leaders .
# ********************
# Annotations:
# But <SIG0>as</SIG0> <ARG0>we work for the people</ARG0> , <ARG1>we obliged their request and released the men</ARG1> , ” said a Maoist leader who handed over the abducted to the tribal leaders .
# ----
# But as we work for the people , <ARG0>we obliged their request</ARG0> and <ARG1>released the men</ARG1> , ” said a Maoist leader who handed over the abducted to the tribal leaders .
#
#
#
# Sentence:
# This strike is causing huge disruptions and all because of a one percent wage increase .
# ********************
# Annotations:
# <ARG1>This strike</ARG1> is causing huge disruptions and <SIG0>all because of</SIG0> <ARG0>a one percent wage increase</ARG0> .
# ----
# <ARG0>This strike</ARG0> <ARG1><SIG0>is causing</SIG0> huge disruptions</ARG1> and all because of a one percent wage increase .
#
#
#
# Sentence:
# “ I think independent film producers have the responsibility to document what mainstream media failed to report on. ” But on the eve of the protests ’ second anniversary , Chan claims all of Hong Kong ’ s major cinemas are refusing to show his film , the result , he suspects , of creeping self-censorship as businesses shy away from offending Beijing .
# ********************
# Annotations:
# “ I think independent film producers have the responsibility to document what mainstream media failed to report on. ” But on the eve of the protests ’ second anniversary , Chan claims <ARG1>all of Hong Kong ’ s major cinemas are refusing to show his film</ARG1> , <SIG0>the result , he suspects , of</SIG0> <ARG0>creeping self-censorship</ARG0> as businesses shy away from offending Beijing .
# ----
# “ I think independent film producers have the responsibility to document what mainstream media failed to report on. ” But on the eve of the protests ’ second anniversary , Chan claims all of Hong Kong ’ s major cinemas are refusing to show his film , the result , he suspects , of <ARG1>creeping self-censorship</ARG1> <SIG0>as</SIG0> <ARG0>businesses shy away from offending Beijing</ARG0> .
#
#
#
# Sentence:
# Will the unprecedented protests embolden them to fight for their beliefs in future , or convince them that resistance to Beijing ’ s will is futile ?
# ********************
# Annotations:
# Will <ARG0>the unprecedented protests</ARG0> <ARG1><SIG1>embolden</SIG1> them to fight for their beliefs in future , or <SIG0>convince</SIG0> them that resistance to Beijing ’ s will is futile</ARG1> ?
# ----
# Will the unprecedented protests <ARG1>embolden them to fight</ARG1> <SIG0>for</SIG0> <ARG0>their beliefs in future</ARG0> , or convince them that resistance to Beijing ’ s will is futile ?
#
#
#
# Sentence:
# DA MP Andrew Whitfield said he would ask police commissioner General Khehla Sitole to activate the National Joint Operations and Intelligence Structure ( Natjoints ) to intervene to curb violence , protect infrastructure and prevent further damage to the economy arising out of events such as looting , attacks on foreign nationals and the torching of trucks in an ongoing labour protest .
# ********************
# Annotations:
# DA MP Andrew Whitfield said <ARG1>he would ask police commissioner General Khehla Sitole</ARG1> <ARG0><SIG0>to</SIG0> activate the National Joint Operations and Intelligence Structure ( Natjoints )</ARG0> to intervene to curb violence , protect infrastructure and prevent further damage to the economy arising out of events such as looting , attacks on foreign nationals and the torching of trucks in an ongoing labour protest .
# ----
# DA MP Andrew Whitfield said he would ask police commissioner General Khehla Sitole <ARG1>to activate the National Joint Operations and Intelligence Structure ( Natjoints )</ARG1> <ARG0><SIG0>to</SIG0> intervene</ARG0> to curb violence , protect infrastructure and prevent further damage to the economy arising out of events such as looting , attacks on foreign nationals and the torching of trucks in an ongoing labour protest .
# ----
# DA MP Andrew Whitfield said he would ask police commissioner General Khehla Sitole to activate the National Joint Operations and Intelligence Structure ( Natjoints ) <ARG1>to intervene</ARG1> <ARG0><SIG0>to</SIG0> curb violence , protect infrastructure and prevent further damage to the economy</ARG0> arising out of events such as looting , attacks on foreign nationals and the torching of trucks in an ongoing labour protest .
# ----
# DA MP Andrew Whitfield said he would ask police commissioner General Khehla Sitole to activate the National Joint Operations and Intelligence Structure ( Natjoints ) to intervene to curb violence , protect infrastructure and prevent further <ARG1>damage to the economy</ARG1> <SIG0>arising out of</SIG0> <ARG0>events such as looting , attacks on foreign nationals and the torching of trucks in an ongoing labour protest</ARG0> .
#
#
#
# Sentence:
# As the Muslims and tribals clashed , eight people were injured in police firing .
# ********************
# Annotations:
# As the Muslims and tribals clashed , <ARG1>eight people were injured</ARG1> in <ARG0>police firing</ARG0> .
# ----
# <SIG0>As</SIG0> <ARG0>the Muslims and tribals clashed</ARG0> , eight people were injured in <ARG1>police firing</ARG1> .

# %%
print(f"Total multiannotation cases: {total_multianncases}/{len(multiann_dict)}")
# Out:
# Total multiannotation cases: 20/160

# %% [markdown]
# There is significant amount of multiple annotations per sentence! Every 8th example contains more than 1 triplet!
